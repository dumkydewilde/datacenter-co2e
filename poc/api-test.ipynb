# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.mgmt.resource import ResourceManagementClient, SubscriptionClient
from azure.mgmt.compute import ComputeManagementClient

import requests, json, os

# Acquire a credential object
credential = InteractiveBrowserCredential()

CLIMATIQ_KEY = "J00J1VB0J9M1H8Q3TRP7GTTHXPFG"

# %%
credential.authenticate()

# %%
REGION_MAPPING = {
    "azure" : {
        "australiacentral": "australia_central",
        "australiacentral2": "australia_central_2",
        "australiaeast": "australia_east",
        "australiasoutheast": "australia_south_east",
        "brazilsouth": "brazil_south",
        "brazilsoutheast": "brazil_south_east",
        "canadacentral": "canada_central",
        "canadaeast": "canada_east",
        "centralindia": "central_india",
        "centralus": "central_us",
        "eastasia": "east_asia",
        "eastus": "east_us",
        "eastus2": "east_us_2",
        "eastus3": "east_us_3",
        "francecentral": "france_central",
        "francesouth": "france_south",
        "germanynorth": "germany_north",
        "germanywestcentral": "germany_west_central",
        "indiacentral": "india_central",
        "indiasouth": "india_south",
        "indiawest": "india_west",
        "japaneast": "japan_east",
        "japanwest": "japan_west",
        "koreaeast": "korea_east",
        "koreasouth": "korea_south",
        "northcentralus": "north_central_us",
        "northeurope": "north_europe",
        "norwayeast": "norway_east",
        "norwaywest": "norway_west",
        "southafrica": "south_africa",
        "southafricanorth": "south_africa_north",
        "southafricawest": "south_africa_west",
        "southcentralus": "south_central_us",
        "southindia": "south_india",
        "southeastasia": "southeast_asia",
        "switzerlandnorth": "switzerland_north",
        "switzerlandwest": "switzerland_west",
        "uksouth": "uk_south",
        "ukwest": "uk_west",
        "unitedarabemirates": "united_arab_emirates",
        "unitedarabemiratescentral": "united_arab_emirates_central",
        "unitedarabemiratesnorth": "united_arab_emirates_north",
        "westcentralus": "west_central_us",
        "westeurope": "west_europe",
        "westindia": "west_india",
        "westus": "west_us",
        "westus2": "west_us_2",
        "westus3": "west_us_3"
    }
}

# %%
# Retrieve subscription ID from environment variable.
gdd_subscription_id = "5ddf05c0-b972-44ca-b90a-3e49b5de80dd" # GDD playground

def get_available_vms(credential, subscription_id):
    client = ComputeManagementClient(credential, subscription_id)

    vm_list_details = {
        sku.name: {
            "tier": sku.tier,
            "size": sku.size,
            "vCPUS": int([c.value for c in sku.capabilities if str(c.name) == "vCPUs"][0]),
            "capabilities" : {c.name : c.value for c in sku.capabilities}
        } for sku in client.resource_skus.list() if "virtualMachine" in sku.resource_type }

    return vm_list_details

def get_az_resources(credential, subscription_ids=[], databricks_only=False):
    resources = []

    if isinstance(subscription_ids, str):
        subscription_ids = [subscription_ids]

    # If no subscription is specified, get all subscriptions for the credential
    if len(subscription_ids) == 0:
        subs = SubscriptionClient(credential)
        subscription_ids = [sub.subscription_id for sub in list(subs.subscriptions.list())]
    
    for subscription_id in subscription_ids:
        available_vms = []
        resource_client = ResourceManagementClient(credential, subscription_id)
        group_list = list(resource_client.resource_groups.list())

        print(f"Fetching {len(group_list)} resources from subscription '{subscription_id}'")

        if databricks_only:
            group_list = [group for group in group_list if "databricks-rg" in group.name]

        for group in group_list:
            for item in resource_client.resources.list_by_resource_group(group.name, expand="createdTime"):
                if item.type in ["Microsoft.Storage/storageAccounts", "Microsoft.Compute/virtualMachines"]:
                    resource_dict = {
                        "group_name": group.name, 
                        "group_is_databricks": "databricks-rg" in group.name,
                        "item_id": item.id,
                        "item_type": item.type,
                        "item_name": item.name,
                        "item_location": item.location,
                        "item_created_time": str(item.created_time)
                    }

                    resource_details = resource_client.resources.get_by_id(item.id, api_version="2021-04-01")

                    if "hardwareProfile" in resource_details.properties:
                        resource_dict["vm_name"] = resource_details.properties["hardwareProfile"]["vmSize"]

                        if len(available_vms) == 0:
                            print(f"Fetching available vms for subscription '{subscription_id}'")
                            available_vms = get_available_vms(credential, subscription_id)
                        
                        if resource_dict["vm_name"] in available_vms.keys():
                            resource_dict["num_cpus"] = available_vms[resource_dict["vm_name"]]["vCPUS"]

                    resources.append(resource_dict)

    return resources

# %%
az_resources = get_az_resources(credential)
# Out:
# Fetching 19 resources from subscription '1e663d00-d459-4c1d-88ba-7877566362e6'
# Fetching available vms for subscription '1e663d00-d459-4c1d-88ba-7877566362e6'
# Fetching 12 resources from subscription '93003cb9-c1a6-48d2-b9a9-757ca760743e'
# Fetching available vms for subscription '93003cb9-c1a6-48d2-b9a9-757ca760743e'

# %%
vms = get_available_vms(credential, '1e663d00-d459-4c1d-88ba-7877566362e6')

# %%
vms
# Out:
# {'Basic_A0': {'tier': 'Basic',
#   'size': 'A0',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '20480',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '0.75',
#    'MaxDataDiskCount': '1',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '50',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Basic_A1': {'tier': 'Basic',
#   'size': 'A1',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '40960',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '1.75',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Basic_A2': {'tier': 'Basic',
#   'size': 'A2',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '61440',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '3.5',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Basic_A3': {'tier': 'Basic',
#   'size': 'A3',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '122880',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '7',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Basic_A4': {'tier': 'Basic',
#   'size': 'A4',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '245760',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A0': {'tier': 'Standard',
#   'size': 'A0',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '20480',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '0.75',
#    'MaxDataDiskCount': '1',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '50',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A1': {'tier': 'Standard',
#   'size': 'A1',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '71680',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '1.75',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A1_v2': {'tier': 'Standard',
#   'size': 'A1_v2',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '10240',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '2',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '1000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '20971520',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '10485760',
#    'UncachedDiskIOPS': '1600',
#    'UncachedDiskBytesPerSecond': '24000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A2': {'tier': 'Standard',
#   'size': 'A2',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '138240',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '3.5',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '2000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '41943040',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '20971520',
#    'UncachedDiskIOPS': '3200',
#    'UncachedDiskBytesPerSecond': '48000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A2m_v2': {'tier': 'Standard',
#   'size': 'A2m_v2',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '20480',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '16',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '2000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '41943040',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '20971520',
#    'UncachedDiskIOPS': '3200',
#    'UncachedDiskBytesPerSecond': '48000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A2_v2': {'tier': 'Standard',
#   'size': 'A2_v2',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '20480',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '4',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '2000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '41943040',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '20971520',
#    'UncachedDiskIOPS': '3200',
#    'UncachedDiskBytesPerSecond': '48000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A3': {'tier': 'Standard',
#   'size': 'A3',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '291840',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '7',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '4000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '83886080',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '41943040',
#    'UncachedDiskIOPS': '6400',
#    'UncachedDiskBytesPerSecond': '96000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A4': {'tier': 'Standard',
#   'size': 'A4',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '619520',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_A4m_v2': {'tier': 'Standard',
#   'size': 'A4m_v2',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '40960',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '32',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '4000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '83886080',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '41943040',
#    'UncachedDiskIOPS': '6400',
#    'UncachedDiskBytesPerSecond': '96000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_A4_v2': {'tier': 'Standard',
#   'size': 'A4_v2',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '40960',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '8',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '4000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '83886080',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '41943040',
#    'UncachedDiskIOPS': '6400',
#    'UncachedDiskBytesPerSecond': '96000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_A5': {'tier': 'Standard',
#   'size': 'A5',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '138240',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '2000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '41943040',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '20971520',
#    'UncachedDiskIOPS': '3200',
#    'UncachedDiskBytesPerSecond': '48000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A6': {'tier': 'Standard',
#   'size': 'A6',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '291840',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '28',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '4000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '83886080',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '41943040',
#    'UncachedDiskIOPS': '6400',
#    'UncachedDiskBytesPerSecond': '96000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_A7': {'tier': 'Standard',
#   'size': 'A7',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '619520',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '8000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '167772160',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '83886080',
#    'UncachedDiskIOPS': '12800',
#    'UncachedDiskBytesPerSecond': '192000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_A8m_v2': {'tier': 'Standard',
#   'size': 'A8m_v2',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '81920',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '8000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '167772160',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '83886080',
#    'UncachedDiskIOPS': '12800',
#    'UncachedDiskBytesPerSecond': '192000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_A8_v2': {'tier': 'Standard',
#   'size': 'A8_v2',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '81920',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '16',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '100',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '8000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '167772160',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '83886080',
#    'UncachedDiskIOPS': '12800',
#    'UncachedDiskBytesPerSecond': '192000000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_B12ms': {'tier': 'Standard',
#   'size': 'B12ms',
#   'vCPUS': 12,
#   'capabilities': {'MaxResourceVolumeMB': '98304',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '12',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '48',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '12',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '6480',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '74956800',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '74956800',
#    'CachedDiskBytes': '32212254720',
#    'UncachedDiskIOPS': '4320',
#    'UncachedDiskBytesPerSecond': '50000000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '6'}},
#  'Standard_B16ms': {'tier': 'Standard',
#   'size': 'B16ms',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '131072',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'CombinedTempDiskAndCachedIOPS': '8640',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '104857600',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '104857600',
#    'UncachedDiskIOPS': '4320',
#    'UncachedDiskBytesPerSecond': '52428800',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_B1ls': {'tier': 'Standard',
#   'size': 'B1ls',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '4096',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '0.5',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '1',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '200',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '22528000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '22528000',
#    'CachedDiskBytes': '32212254720',
#    'UncachedDiskIOPS': '320',
#    'UncachedDiskBytesPerSecond': '22500000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_B1ms': {'tier': 'Standard',
#   'size': 'B1ms',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '4096',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '2',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '1',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '800',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '22528000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '22528000',
#    'CachedDiskBytes': '32212254720',
#    'UncachedDiskIOPS': '640',
#    'UncachedDiskBytesPerSecond': '22500000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_B1s': {'tier': 'Standard',
#   'size': 'B1s',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '4096',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '1',
#    'MaxDataDiskCount': '2',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '1',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '400',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '22528000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '22528000',
#    'CachedDiskBytes': '32212254720',
#    'UncachedDiskIOPS': '320',
#    'UncachedDiskBytesPerSecond': '22500000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_B20ms': {'tier': 'Standard',
#   'size': 'B20ms',
#   'vCPUS': 20,
#   'capabilities': {'MaxResourceVolumeMB': '163840',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '20',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '80',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '20',
#    'CombinedTempDiskAndCachedIOPS': '10800',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '131072000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '131072000',
#    'UncachedDiskIOPS': '4320',
#    'UncachedDiskBytesPerSecond': '52428800',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_B2ms': {'tier': 'Standard',
#   'size': 'B2ms',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '16384',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '8',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '2',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '2400',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '23592960',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '23592960',
#    'UncachedDiskIOPS': '1920',
#    'UncachedDiskBytesPerSecond': '23592960',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '3'}},
#  'Standard_B2s': {'tier': 'Standard',
#   'size': 'B2s',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '8192',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '4',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '2',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '1600',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '22528000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '22528000',
#    'CachedDiskBytes': '32212254720',
#    'UncachedDiskIOPS': '1280',
#    'UncachedDiskBytesPerSecond': '22500000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '3'}},
#  'Standard_B4ms': {'tier': 'Standard',
#   'size': 'B4ms',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '32768',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '16',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '4',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '3600',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '36700160',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '36700160',
#    'UncachedDiskIOPS': '2880',
#    'UncachedDiskBytesPerSecond': '36700160',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_B8ms': {'tier': 'Standard',
#   'size': 'B8ms',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '65536',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '32',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '8',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '4320',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '52428800',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '52428800',
#    'UncachedDiskIOPS': '4320',
#    'UncachedDiskBytesPerSecond': '52428800',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_D1': {'tier': 'Standard',
#   'size': 'D1',
#   'vCPUS': 1,
#   'capabilities': {'MaxResourceVolumeMB': '51200',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '1',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '3.5',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '1',
#    'ACUs': '160',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '3000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '48234496',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '24117248',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_D11': {'tier': 'Standard',
#   'size': 'D11',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '102400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '160',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '6000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '97517568',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '48234496',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_D11_v2': {'tier': 'Standard',
#   'size': 'D11_v2',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '102400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '6000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '97517568',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '48234496',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_D11_v2_Promo': {'tier': 'Standard',
#   'size': 'D11_v2_Promo',
#   'vCPUS': 2,
#   'capabilities': {'MaxResourceVolumeMB': '102400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '2',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '2',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '6000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '97517568',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '48234496',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_D12': {'tier': 'Standard',
#   'size': 'D12',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '204800',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '28',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '160',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '12000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '196083712',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '97517568',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_D12_v2': {'tier': 'Standard',
#   'size': 'D12_v2',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '204800',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '28',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '12000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '196083712',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '97517568',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_D12_v2_Promo': {'tier': 'Standard',
#   'size': 'D12_v2_Promo',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '204800',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '28',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '4',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '12000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '196083712',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '97517568',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_D13': {'tier': 'Standard',
#   'size': 'D13',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '409600',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '160',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '24000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '393216000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '196083712',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D13_v2': {'tier': 'Standard',
#   'size': 'D13_v2',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '409600',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '24000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '393216000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '196083712',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D13_v2_Promo': {'tier': 'Standard',
#   'size': 'D13_v2_Promo',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '409600',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '8',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '24000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '393216000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '196083712',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D14': {'tier': 'Standard',
#   'size': 'D14',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '819200',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '160',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '48000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '786432000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '393216000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D14_v2': {'tier': 'Standard',
#   'size': 'D14_v2',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '819200',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '48000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '786432000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '393216000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D14_v2_Promo': {'tier': 'Standard',
#   'size': 'D14_v2_Promo',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '819200',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '48000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '786432000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '393216000',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D15_v2': {'tier': 'Standard',
#   'size': 'D15_v2',
#   'vCPUS': 20,
#   'capabilities': {'MaxResourceVolumeMB': '1024000',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '20',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '140',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '20',
#    'ACUs': '210',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '60000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '982515712',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '490733568',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16ads_v5': {'tier': 'Standard',
#   'size': 'D16ads_v5',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'HibernationSupported': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'PaaS,IaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '230',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '75000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '1048576000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '268435456',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '402653184',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16as_v4': {'tier': 'Standard',
#   'size': 'D16as_v4',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '131072',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '32000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '268435456',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '268435456',
#    'CachedDiskBytes': '429496729600',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '402653184',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16as_v5': {'tier': 'Standard',
#   'size': 'D16as_v5',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '0',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'HibernationSupported': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '230',
#    'vCPUsPerCore': '2',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '402653184',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16a_v4': {'tier': 'Standard',
#   'size': 'D16a_v4',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '409600',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16ds_v4': {'tier': 'Standard',
#   'size': 'D16ds_v4',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '195',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '154000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '967835648',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '484442112',
#    'CachedDiskBytes': '429496729600',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '402653184',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16ds_v5': {'tier': 'Standard',
#   'size': 'D16ds_v5',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'HibernationSupported': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '154000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '1048576000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '1048576000',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '629145600',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16d_v4': {'tier': 'Standard',
#   'size': 'D16d_v4',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS,PaaS',
#    'vCPUsAvailable': '16',
#    'ACUs': '195',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '154000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '967835648',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '483393536',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16d_v5': {'tier': 'Standard',
#   'size': 'D16d_v5',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '154000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '1048576000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '1048576000',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '629145600',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_D16pds_v5': {'tier': 'Standard',
#   'size': 'D16pds_v5',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '614400',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'True',
#    'HyperVGenerations': 'V2',
#    'MemoryGB': '64',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'Arm64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'vCPUsPerCore': '1',
#    'CombinedTempDiskAndCachedIOPS': '75000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '1000000000',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '1000000000',
#    'CachedDiskBytes': '429496729600',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '600000000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
# ...
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '12',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_NV12_Promo': {'tier': 'Standard',
#   'size': 'NV12_Promo',
#   'vCPUS': 12,
#   'capabilities': {'MaxResourceVolumeMB': '696320',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '12',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '48',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '12',
#    'GPUs': '2',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_NV16as_v4': {'tier': 'Standard',
#   'size': 'NV16as_v4',
#   'vCPUS': 16,
#   'capabilities': {'MaxResourceVolumeMB': '360448',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '16',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '16',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV18ads_A10_v5': {'tier': 'Standard',
#   'size': 'NV18ads_A10_v5',
#   'vCPUS': 18,
#   'capabilities': {'MaxResourceVolumeMB': '737280',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '18',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '220',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '18',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '32000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '268435456',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '268435456',
#    'CachedDiskBytes': '429497000000',
#    'UncachedDiskIOPS': '25600',
#    'UncachedDiskBytesPerSecond': '402653184',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '6'}},
#  'Standard_NV24': {'tier': 'Standard',
#   'size': 'NV24',
#   'vCPUS': 24,
#   'capabilities': {'MaxResourceVolumeMB': '1474560',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '24',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '224',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '24',
#    'GPUs': '4',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_NV24s_v2': {'tier': 'Standard',
#   'size': 'NV24s_v2',
#   'vCPUS': 24,
#   'capabilities': {'MaxResourceVolumeMB': '1376256',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '24',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '448',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '24',
#    'GPUs': '4',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV24s_v3': {'tier': 'Standard',
#   'size': 'NV24s_v3',
#   'vCPUS': 24,
#   'capabilities': {'MaxResourceVolumeMB': '688128',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '24',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '224',
#    'MaxDataDiskCount': '24',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '24',
#    'GPUs': '2',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV24_Promo': {'tier': 'Standard',
#   'size': 'NV24_Promo',
#   'vCPUS': 24,
#   'capabilities': {'MaxResourceVolumeMB': '1474560',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '24',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '224',
#    'MaxDataDiskCount': '64',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '24',
#    'GPUs': '4',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_NV32as_v4': {'tier': 'Standard',
#   'size': 'NV32as_v4',
#   'vCPUS': 32,
#   'capabilities': {'MaxResourceVolumeMB': '720896',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '32',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '32',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV36adms_A10_v5': {'tier': 'Standard',
#   'size': 'NV36adms_A10_v5',
#   'vCPUS': 36,
#   'capabilities': {'MaxResourceVolumeMB': '2949120',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '36',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '880',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '36',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '8000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '125829120',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '125829120',
#    'CachedDiskBytes': '1099511627776',
#    'UncachedDiskIOPS': '12000',
#    'UncachedDiskBytesPerSecond': '184320000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV36ads_A10_v5': {'tier': 'Standard',
#   'size': 'NV36ads_A10_v5',
#   'vCPUS': 36,
#   'capabilities': {'MaxResourceVolumeMB': '1468006',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '36',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '440',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '36',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '64000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '536870912',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '536870912',
#    'CachedDiskBytes': '858993000000',
#    'UncachedDiskIOPS': '51200',
#    'UncachedDiskBytesPerSecond': '805306368',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV48s_v3': {'tier': 'Standard',
#   'size': 'NV48s_v3',
#   'vCPUS': 48,
#   'capabilities': {'MaxResourceVolumeMB': '3018752',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '48',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '448',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '48',
#    'GPUs': '4',
#    'vCPUsPerCore': '2',
#    'CachedDiskBytes': '1374389534720',
#    'UncachedDiskIOPS': '80000',
#    'UncachedDiskBytesPerSecond': '1200000000000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV4as_v4': {'tier': 'Standard',
#   'size': 'NV4as_v4',
#   'vCPUS': 4,
#   'capabilities': {'MaxResourceVolumeMB': '90112',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '4',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '14',
#    'MaxDataDiskCount': '8',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '4',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_NV6': {'tier': 'Standard',
#   'size': 'NV6',
#   'vCPUS': 6,
#   'capabilities': {'MaxResourceVolumeMB': '389120',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '6',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '24',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '6',
#    'GPUs': '1',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_NV6ads_A10_v5': {'tier': 'Standard',
#   'size': 'NV6ads_A10_v5',
#   'vCPUS': 6,
#   'capabilities': {'MaxResourceVolumeMB': '184320',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '6',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '55',
#    'MaxDataDiskCount': '4',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '4',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '8000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '67108864',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '67108864',
#    'CachedDiskBytes': '107374000000',
#    'UncachedDiskIOPS': '6400',
#    'UncachedDiskBytesPerSecond': '100663296',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_NV6s_v2': {'tier': 'Standard',
#   'size': 'NV6s_v2',
#   'vCPUS': 6,
#   'capabilities': {'MaxResourceVolumeMB': '344064',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '6',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '12',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '6',
#    'GPUs': '1',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_NV6_Promo': {'tier': 'Standard',
#   'size': 'NV6_Promo',
#   'vCPUS': 6,
#   'capabilities': {'MaxResourceVolumeMB': '389120',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '6',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1',
#    'MemoryGB': '56',
#    'MaxDataDiskCount': '24',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'False',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '6',
#    'GPUs': '1',
#    'vCPUsPerCore': '1',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'False',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '2'}},
#  'Standard_NV72ads_A10_v5': {'tier': 'Standard',
#   'size': 'NV72ads_A10_v5',
#   'vCPUS': 72,
#   'capabilities': {'MaxResourceVolumeMB': '2949120',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '72',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '880',
#    'MaxDataDiskCount': '32',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '72',
#    'GPUs': '2',
#    'vCPUsPerCore': '2',
#    'CombinedTempDiskAndCachedIOPS': '96000',
#    'CombinedTempDiskAndCachedReadBytesPerSecond': '805306368',
#    'CombinedTempDiskAndCachedWriteBytesPerSecond': '805306368',
#    'CachedDiskBytes': '1099511627776',
#    'UncachedDiskIOPS': '12000',
#    'UncachedDiskBytesPerSecond': '180000000',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '8'}},
#  'Standard_NV8as_v4': {'tier': 'Standard',
#   'size': 'NV8as_v4',
#   'vCPUS': 8,
#   'capabilities': {'MaxResourceVolumeMB': '180224',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '8',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '28',
#    'MaxDataDiskCount': '16',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'True',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'vCPUsAvailable': '8',
#    'GPUs': '1',
#    'vCPUsPerCore': '2',
#    'EphemeralOSDiskSupported': 'True',
#    'EncryptionAtHostSupported': 'True',
#    'CapacityReservationSupported': 'False',
#    'TrustedLaunchDisabled': 'True',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '4'}},
#  'Standard_PB6s': {'tier': 'Standard',
#   'size': 'PB6s',
#   'vCPUS': 6,
#   'capabilities': {'MaxResourceVolumeMB': '344064',
#    'OSVhdSizeMB': '1047552',
#    'vCPUs': '6',
#    'MemoryPreservingMaintenanceSupported': 'False',
#    'HyperVGenerations': 'V1,V2',
#    'MemoryGB': '112',
#    'MaxDataDiskCount': '12',
#    'CpuArchitectureType': 'x64',
#    'LowPriorityCapable': 'False',
#    'PremiumIO': 'True',
#    'VMDeploymentTypes': 'IaaS',
#    'EphemeralOSDiskSupported': 'False',
#    'EncryptionAtHostSupported': 'False',
#    'CapacityReservationSupported': 'False',
#    'AcceleratedNetworkingEnabled': 'True',
#    'RdmaEnabled': 'False',
#    'MaxNetworkInterfaces': '1'}}}

# %%
def get_monitoring_metric(resource_id: str, metrics: list, credential, timespan):
    token =credential.get_token("https://management.azure.com/user_impersonation")
    metrics = ",".join(metrics)
    
    url = f"https://management.azure.com/{resource_id}/providers/microsoft.insights/metrics?api-version=2018-01-01&metricnames={metrics}&timespan={timespan}"
    headers = {"Authorization" : f"Bearer {token.token}"}
    params = {"aggregation" : "average", "interval": "P1D"}

    res = requests.get(url, headers=headers, params=params)

    return json.loads(res.text)

# %%
metrics = ["Percentage CPU"]
timespan = "2022-09-07T01:00:00Z/2022-10-16T00:00:00Z"

for r in az_resources:
    if r["item_type"] == "Microsoft.Compute/virtualMachines":
        usage = get_monitoring_metric(r["item_id"], metrics, credential, timespan)
        r["usage"] = {
            "metrics": metrics,
            "cost" : usage["cost"],
            "data": [t["data"] for t in usage["value"][0]["timeseries"]] # take first statistic (avg) for all metrics in resource
        }

# %%
az_resources[:2]
# Out:
# [{'group_name': 'rg-vckgdp-terra-uprod',
#   'group_is_databricks': False,
#   'item_id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/resourceGroups/rg-vckgdp-terra-uprod/providers/Microsoft.Storage/storageAccounts/stvckgdpterrauprod',
#   'item_type': 'Microsoft.Storage/storageAccounts',
#   'item_name': 'stvckgdpterrauprod',
#   'item_location': 'westeurope',
#   'item_created_time': '2021-09-23 13:17:23.738956+00:00'},
#  {'group_name': 'rg-vckgdp-terra-udev',
#   'group_is_databricks': False,
#   'item_id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/resourceGroups/rg-vckgdp-terra-udev/providers/Microsoft.Storage/storageAccounts/stvckgdpterraudev',
#   'item_type': 'Microsoft.Storage/storageAccounts',
#   'item_name': 'stvckgdpterraudev',
#   'item_location': 'westeurope',
#   'item_created_time': '2021-09-23 13:21:09.287786+00:00'}]

# %%
def get_co2_data():
    if not "CO2_DATA" in globals():
        set_co2_data({
            "cpu": {},
            "memory": {},
            "storage": {}
        })
    
    return CO2_DATA


def set_co2_data(co2_data):
    global CO2_DATA
    CO2_DATA = co2_data

    return CO2_DATA


def get_climatiq_api_key():
    if "CLIMATIQ_KEY" in globals():
        return CLIMATIQ_KEY
    elif "CLIMATIQ_KEY" in os.environ():
        return os.environ.get("CLIMATIQ_KEY")


def calculate_compute_emission(provider, region, cpu_count, cpu_load, duration, duration_unit):
    co2_data = get_co2_data()
    climatiq_api_key = get_climatiq_api_key()

    # normalise region
    region_mapping = REGION_MAPPING
    if region in region_mapping[provider].keys():
        region = region_mapping[provider][region]
    
    # Fetch data for calculation if not exists
    if not provider in co2_data["cpu"].keys():
        co2_data["cpu"][provider] = {}
        co2_data["cpu"][provider][region] = retrieve_climatiq_data(climatiq_api_key, provider, region)["co2e"]
        set_co2_data(co2_data)

    if not region in co2_data["cpu"][provider].keys():
        co2_data["cpu"][provider][region] = retrieve_climatiq_data(climatiq_api_key, provider, region)["co2e"]
        set_co2_data(co2_data)

    # Normalise to hourly units
    if duration_unit == "minute":
        duration = duration / 60
    elif duration_unit == "day":
        duration = duration * 24

    # Normalise cpu load if used in percentage
    if cpu_load > 1:
        cpu_load = cpu_load / 100

    return CO2_DATA["cpu"][provider][region] * cpu_count * cpu_load * duration


def retrieve_climatiq_data(api_key, provider, region, type="cpu", duration=1, duration_unit="h"):
    url = f"https://beta3.api.climatiq.io/compute/{provider}/{type}"
    headers = {"Authorization" : f"Bearer {api_key}"}

    data = {
        "cpu_count": 1,
        "region": region,
        "cpu_load": 1,
        "duration": int(duration),
        "duration_unit": duration_unit
    }

    res = requests.post(url, headers=headers, json=data)

    if not str(res.status_code)[0] == "2":
        raise Exception(f"Error calling climatiq API: {res.text}")

    return res.json()

# %%
import pandas as pd

import plotly.express as px
import plotly.graph_objs as go

pd.options.plotting.backend = "plotly"

# %%
data = []

for r in az_resources:
    if "usage" in r.keys():
        data.extend([(
                f"{r['group_name']} - {r['item_name']}", 
                r["item_location"],
                r["num_cpus"],
                val["timeStamp"].split("T")[0], 
                val["average"]
            ) for val in r["usage"]["data"][0] if "average" in val.keys()] 
        )

data[0]
# Out:
# ('rg-vckgdp-inges-udev - vm-vckgdp-inges-udev',
#  'westeurope',
#  2,
#  '2022-09-15',
#  11.21287599861063)

# %%
df = pd.DataFrame(data, columns=["group_name", "location", "num_cpus", "date", "avg_cpu_utilisation"])
df["date"] = pd.to_datetime(df["date"])
df = df.set_index("date")
df.head()
# Out:
#                                              group_name    location  num_cpus  \
# date
# 2022-09-15  rg-vckgdp-inges-udev - vm-vckgdp-inges-udev  westeurope         2
# 2022-09-16  rg-vckgdp-inges-udev - vm-vckgdp-inges-udev  westeurope         2
# 2022-09-17  rg-vckgdp-inges-udev - vm-vckgdp-inges-udev  westeurope         2
# 2022-09-18  rg-vckgdp-inges-udev - vm-vckgdp-inges-udev  westeurope         2
# 2022-09-19  rg-vckgdp-inges-udev - vm-vckgdp-inges-udev  westeurope         2
#
#             avg_cpu_utilisation
# date
# 2022-09-15            11.212876
# 2022-09-16             9.177477
# 2022-09-17             9.139667
# 2022-09-18             8.846148
# 2022-09-19             8.791565

# %%
df["co2e_kg"] = df.apply(lambda row: calculate_compute_emission("azure", row["location"], row["num_cpus"], row["avg_cpu_utilisation"], 1, "day"), axis=1)

# %%
def get_co2_equivalent(co2_kg, type="car_kilometers"):
    if type == "car_kilometers":
        # Equivalent KMs for Toyota Corolla 2020 (i.e. most popular car in the world)
        factor = 0.196974607

    return f"{round(co2_kg * factor, 2)} {type}"

get_co2_equivalent(df["co2e_kg"].sum())
# Out:
# '0.17 car_kilometers'

# %%
fig = px.bar(df, x=df.index, y="co2e_kg", color="group_name", template="plotly_dark")
fig.update_layout(legend=dict(orientation="h", y=-0.3))
fig.show()
