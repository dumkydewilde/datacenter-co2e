# %%
import requests, json, os
from climatiq import climatiq
import pandas as pd

CLIMATIQ_KEY = "J00J1VB0J9M1H8Q3TRP7GTTHXPFG"

with open("region-mapping.json") as f:
    REGION_MAPPING = json.load(f)

with open("azure_regions.json") as f:
    AZURE_REGIONS = json.load(f)

# %%
CLIMATIQ_BASE_URL = "https://beta3.api.climatiq.io"

def get_climatiq_api_key():
    if "CLIMATIQ_KEY" in globals():
        return CLIMATIQ_KEY
    elif "CLIMATIQ_KEY" in os.environ():
        return os.environ.get("CLIMATIQ_KEY")


def calculate_compute_emission(provider, region, cpu_count, cpu_load, duration, duration_unit):
    co2_data = get_co2_data()
    climatiq_api_key = get_climatiq_api_key()

    # normalise region
    region_mapping = REGION_MAPPING
    if region in region_mapping[provider].keys():
        region = region_mapping[provider][region]
    
    # Fetch data for calculation if not exists
    if not provider in co2_data["cpu"].keys():
        co2_data["cpu"][provider] = {}
        co2_data["cpu"][provider][region] = retrieve_climatiq_data(climatiq_api_key, provider, region)["co2e"]
        set_co2_data(co2_data)

    if not region in co2_data["cpu"][provider].keys():
        co2_data["cpu"][provider][region] = retrieve_climatiq_data(climatiq_api_key, provider, region)["co2e"]
        set_co2_data(co2_data)

    # Normalise to hourly units
    if duration_unit == "minute":
        duration = duration / 60
    elif duration_unit == "day":
        duration = duration * 24

    # Normalise cpu load if used in percentage
    if cpu_load > 1:
        cpu_load = cpu_load / 100

    return CO2_DATA["cpu"][provider][region] * cpu_count * cpu_load * duration


def retrieve_climatiq_data(api_key, provider, region, type="cpu", duration=1, duration_unit="h"):
    url = f"https://beta3.api.climatiq.io/compute/{provider}/{type}"
    headers = {"Authorization" : f"Bearer {api_key}"}

    data = {
        "cpu_count": 1,
        "region": region,
        "cpu_load": 1,
        "duration": int(duration),
        "duration_unit": duration_unit
    }

    res = requests.post(url, headers=headers, json=data)

    if not str(res.status_code)[0] == "2":
        raise Exception(f"Error calling climatiq API: {res.text}")

    return res.json()

# %%
def get_metadata(provider=""):
    url = f"https://beta3.api.climatiq.io/compute"
    headers = {"Authorization" : f"Bearer {CLIMATIQ_KEY}"}

    return requests.get(url, headers=headers)
    


providers = get_metadata().json()["cloud_providers"]

with open("provider_metadata.json", "w") as f:
    f.write(json.dumps(providers, indent=4))

# %%
provider_name = "azure"
instances = [i for i in providers[provider_name]["virtual_machine_instances"] if "4_" in i]

instance_data = []

for inst in instances:
    for provider_zone, climatiq_zone in REGION_MAPPING[provider_name].items():

        try:
            zone_details = list(filter(lambda x: x["name"] == provider_zone, AZURE_REGIONS))[0]
            
            item = {
            "provider" : provider_name,
            "dc_id" : provider_zone,
            "dc_cq_id" : climatiq_zone,
            "data center name" : zone_details["displayName"],
            "geo" : zone_details["metadata"],
            "activity_type" : "cpu",
            "activity_sub_type" : inst,
            "activity_sub_type_properties" : {"num_cpus": 4},
            "duration_int" : 1,
            "duration_type" : "hour",
            "emission_details" : retrieve_climatiq_data(CLIMATIQ_KEY, provider_name, climatiq_zone)
            }

            print(item)
            instance_data.append(item)

        except Exception as e:
            print(f"Failed to add data for zone: {provider_name} — {provider_zone}. With error {e}")
# Out:
# {'provider': 'azure', 'dc_id': 'australiacentral', 'dc_cq_id': 'australia_central', 'data center name': 'Australia Central', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '-35.3075', 'longitude': '149.1244', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/australiacentral', 'name': 'australiacentral', 'subscriptionId': None}], 'physicalLocation': 'Canberra', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0020175, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_australia_central', 'uuid': '1a5aec93-9ec5-48b7-858a-6197fe6aad9e', 'id': 'cpu-provider_azure-region_australia_central', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'AU-CBR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0020175, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'australiacentral2', 'dc_cq_id': 'australia_central_2', 'data center name': 'Australia Central 2', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '-35.3075', 'longitude': '149.1244', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/australiacentral2', 'name': 'australiacentral2', 'subscriptionId': None}], 'physicalLocation': 'Canberra', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0020175, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_australia_central_2', 'uuid': '436df8ee-1b3c-4419-8337-04ccac5c9d13', 'id': 'cpu-provider_azure-region_australia_central_2', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'AU-CBR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0020175, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'australiaeast', 'dc_cq_id': 'australia_east', 'data center name': 'Australia East', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '-33.86', 'longitude': '151.2094', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/australiasoutheast', 'name': 'australiasoutheast', 'subscriptionId': None}], 'physicalLocation': 'New South Wales', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0020175, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_australia_east', 'uuid': '3632fab3-9143-4509-a29b-34c48dc153d0', 'id': 'cpu-provider_azure-region_australia_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'AU-SYD', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0020175, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'australiasoutheast', 'dc_cq_id': 'australia_south_east', 'data center name': 'Australia Southeast', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '-37.8136', 'longitude': '144.9631', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/australiaeast', 'name': 'australiaeast', 'subscriptionId': None}], 'physicalLocation': 'Victoria', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0024516, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_australia_south_east', 'uuid': 'b7fef7c6-7a79-441b-9c7a-e86d47eadbcf', 'id': 'cpu-provider_azure-region_australia_south_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'AU-MEL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0024516, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'brazilsouth', 'dc_cq_id': 'brazil_south', 'data center name': 'Brazil South', 'geo': {'geographyGroup': 'South America', 'latitude': '-23.55', 'longitude': '-46.633', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southcentralus', 'name': 'southcentralus', 'subscriptionId': None}], 'physicalLocation': 'Sao Paulo State', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0001576, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_brazil_south', 'uuid': 'debee0d0-a537-4540-8d93-6414e71eaa2c', 'id': 'cpu-provider_azure-region_brazil_south', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'BR-SAO', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0001576, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'brazilsoutheast', 'dc_cq_id': 'brazil_south_east', 'data center name': 'Brazil Southeast', 'geo': {'geographyGroup': 'South America', 'latitude': '-22.90278', 'longitude': '-43.2075', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/brazilsouth', 'name': 'brazilsouth', 'subscriptionId': None}], 'physicalLocation': 'Rio', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0001576, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_brazil_south_east', 'uuid': '2619a8c4-1753-4e58-a61b-707233f7cb2f', 'id': 'cpu-provider_azure-region_brazil_south_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'BR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0001576, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'canadacentral', 'dc_cq_id': 'canada_central', 'data center name': 'Canada Central', 'geo': {'geographyGroup': 'Canada', 'latitude': '43.653', 'longitude': '-79.383', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/canadaeast', 'name': 'canadaeast', 'subscriptionId': None}], 'physicalLocation': 'Toronto', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0003064, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_canada_central', 'uuid': '9a27506f-14ac-4efe-aae0-5f4687e8b630', 'id': 'cpu-provider_azure-region_canada_central', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CA-TOR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0003064, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'canadaeast', 'dc_cq_id': 'canada_east', 'data center name': 'Canada East', 'geo': {'geographyGroup': 'Canada', 'latitude': '46.817', 'longitude': '-71.217', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/canadacentral', 'name': 'canadacentral', 'subscriptionId': None}], 'physicalLocation': 'Quebec', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0003064, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_canada_east', 'uuid': 'dee87735-f072-4b8b-b623-40c6d6f17f39', 'id': 'cpu-provider_azure-region_canada_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CA-QUE', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0003064, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'centralindia', 'dc_cq_id': 'central_india', 'data center name': 'Central India', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '18.5822', 'longitude': '73.9197', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southindia', 'name': 'southindia', 'subscriptionId': None}], 'physicalLocation': 'Pune', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.00179611, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_central_india', 'uuid': 'a42dd9e6-6e5e-4ca3-a845-4e3ac8d4dc54', 'id': 'cpu-provider_azure-region_central_india', 'access_type': 'public', 'source': 'CCF', 'year': '2021', 'region': 'IN-PNQ', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.00179611, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'centralus', 'dc_cq_id': 'central_us', 'data center name': 'Central US', 'geo': {'geographyGroup': 'US', 'latitude': '41.5908', 'longitude': '-93.6208', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastus2', 'name': 'eastus2', 'subscriptionId': None}], 'physicalLocation': 'Iowa', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0010885, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_central_us', 'uuid': '6ad0a261-1f6a-48a6-a43a-0cceef0b05af', 'id': 'cpu-provider_azure-region_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-IA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0010885, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'eastasia', 'dc_cq_id': 'east_asia', 'data center name': 'East Asia', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '22.267', 'longitude': '114.188', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southeastasia', 'name': 'southeastasia', 'subscriptionId': None}], 'physicalLocation': 'Hong Kong', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0018132, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_east_asia', 'uuid': '0224361a-4260-4e5a-8e86-a5b32050092f', 'id': 'cpu-provider_azure-region_east_asia', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'HK-HKG', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0018132, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'eastus', 'dc_cq_id': 'east_us', 'data center name': 'East US', 'geo': {'geographyGroup': 'US', 'latitude': '37.3719', 'longitude': '-79.8164', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westus', 'name': 'westus', 'subscriptionId': None}], 'physicalLocation': 'Virginia', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.000968, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_east_us', 'uuid': 'f4744f86-fce7-4453-8a6b-5e3a3561f745', 'id': 'cpu-provider_azure-region_east_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-VA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.000968, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'eastus2', 'dc_cq_id': 'east_us_2', 'data center name': 'East US 2', 'geo': {'geographyGroup': 'US', 'latitude': '36.6681', 'longitude': '-78.3889', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/centralus', 'name': 'centralus', 'subscriptionId': None}], 'physicalLocation': 'Virginia', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.000968, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_east_us_2', 'uuid': '15474187-0919-4afe-94d9-eb38357f0200', 'id': 'cpu-provider_azure-region_east_us_2', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-VA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.000968, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# Failed to add data for zone: azure — eastus3. With error list index out of range
# {'provider': 'azure', 'dc_id': 'francecentral', 'dc_cq_id': 'france_central', 'data center name': 'France Central', 'geo': {'geographyGroup': 'Europe', 'latitude': '46.3772', 'longitude': '2.3730', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/francesouth', 'name': 'francesouth', 'subscriptionId': None}], 'physicalLocation': 'Paris', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.000131, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_france_central', 'uuid': '75c53c16-b293-48c0-b59a-e4b2b7ed34d7', 'id': 'cpu-provider_azure-region_france_central', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'FR-PAR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.000131, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'francesouth', 'dc_cq_id': 'france_south', 'data center name': 'France South', 'geo': {'geographyGroup': 'Europe', 'latitude': '43.8345', 'longitude': '2.1972', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/francecentral', 'name': 'francecentral', 'subscriptionId': None}], 'physicalLocation': 'Marseille', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.000131, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_france_south', 'uuid': 'fdc3f004-c4e9-457c-b444-8d9f2997d0b6', 'id': 'cpu-provider_azure-region_france_south', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'FR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.000131, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'germanynorth', 'dc_cq_id': 'germany_north', 'data center name': 'Germany North', 'geo': {'geographyGroup': 'Europe', 'latitude': '53.073635', 'longitude': '8.806422', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/germanywestcentral', 'name': 'germanywestcentral', 'subscriptionId': None}], 'physicalLocation': 'Berlin', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008649, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_germany_north', 'uuid': '80d1e366-7a32-46e6-96c4-c2036f240bbf', 'id': 'cpu-provider_azure-region_germany_north', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'DE', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008649, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'germanywestcentral', 'dc_cq_id': 'germany_west_central', 'data center name': 'Germany West Central', 'geo': {'geographyGroup': 'Europe', 'latitude': '50.110924', 'longitude': '8.682127', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/germanynorth', 'name': 'germanynorth', 'subscriptionId': None}], 'physicalLocation': 'Frankfurt', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008649, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_germany_west_central', 'uuid': 'd2df8a8f-5095-4d94-b19f-e812c1d45d3a', 'id': 'cpu-provider_azure-region_germany_west_central', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'DE-FRA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008649, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# Failed to add data for zone: azure — indiacentral. With error list index out of range
# Failed to add data for zone: azure — indiasouth. With error list index out of range
# Failed to add data for zone: azure — indiawest. With error list index out of range
# {'provider': 'azure', 'dc_id': 'japaneast', 'dc_cq_id': 'japan_east', 'data center name': 'Japan East', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '35.68', 'longitude': '139.77', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/japanwest', 'name': 'japanwest', 'subscriptionId': None}], 'physicalLocation': 'Tokyo, Saitama', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0011895, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_japan_east', 'uuid': 'dab1b8d0-d729-4a4f-b9a1-75fc878aba36', 'id': 'cpu-provider_azure-region_japan_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'JP-STM', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0011895, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'japanwest', 'dc_cq_id': 'japan_west', 'data center name': 'Japan West', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '34.6939', 'longitude': '135.5022', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/japaneast', 'name': 'japaneast', 'subscriptionId': None}], 'physicalLocation': 'Osaka', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0011895, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_japan_west', 'uuid': '4d54719f-3c2f-4b1d-8535-d8c6d4d1cda0', 'id': 'cpu-provider_azure-region_japan_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'JP-OSA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0011895, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# Failed to add data for zone: azure — koreaeast. With error list index out of range
# {'provider': 'azure', 'dc_id': 'koreasouth', 'dc_cq_id': 'korea_south', 'data center name': 'Korea South', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '35.1796', 'longitude': '129.0756', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/koreacentral', 'name': 'koreacentral', 'subscriptionId': None}], 'physicalLocation': 'Busan', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0010613, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_korea_south', 'uuid': '48e5cb62-f806-4a93-b8d3-ac4338c476e1', 'id': 'cpu-provider_azure-region_korea_south', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'KR', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0010613, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'northcentralus', 'dc_cq_id': 'north_central_us', 'data center name': 'North Central US', 'geo': {'geographyGroup': 'US', 'latitude': '41.8819', 'longitude': '-87.6278', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southcentralus', 'name': 'southcentralus', 'subscriptionId': None}], 'physicalLocation': 'Illinois', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0010486, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_north_central_us', 'uuid': '05438e2c-b4cb-4730-a693-0b08906d7250', 'id': 'cpu-provider_azure-region_north_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-IL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0010486, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'northeurope', 'dc_cq_id': 'north_europe', 'data center name': 'North Europe', 'geo': {'geographyGroup': 'Europe', 'latitude': '53.3478', 'longitude': '-6.2597', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westeurope', 'name': 'westeurope', 'subscriptionId': None}], 'physicalLocation': 'Ireland', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0007115, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_north_europe', 'uuid': '60518249-79a0-4229-8b8d-75977e96c815', 'id': 'cpu-provider_azure-region_north_europe', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'IE', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0007115, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'norwayeast', 'dc_cq_id': 'norway_east', 'data center name': 'Norway East', 'geo': {'geographyGroup': 'Europe', 'latitude': '59.913868', 'longitude': '10.752245', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/norwaywest', 'name': 'norwaywest', 'subscriptionId': None}], 'physicalLocation': 'Norway', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.95e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_norway_east', 'uuid': 'da1409bb-b208-4bf2-9c9b-fc19b1873c21', 'id': 'cpu-provider_azure-region_norway_east', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'NO-OSL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.95e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'norwaywest', 'dc_cq_id': 'norway_west', 'data center name': 'Norway West', 'geo': {'geographyGroup': 'Europe', 'latitude': '58.969975', 'longitude': '5.733107', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/norwayeast', 'name': 'norwayeast', 'subscriptionId': None}], 'physicalLocation': 'Norway', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.95e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_norway_west', 'uuid': 'f0359640-7213-41b9-82c9-e2745c77eff8', 'id': 'cpu-provider_azure-region_norway_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'NO', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.95e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southafrica', 'dc_cq_id': 'south_africa', 'data center name': 'South Africa', 'geo': {'geographyGroup': None, 'latitude': None, 'longitude': None, 'pairedRegion': None, 'physicalLocation': None, 'regionCategory': 'Other', 'regionType': 'Logical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0022999, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_africa', 'uuid': 'bf5fbf27-19ea-4210-8163-12f55bb93224', 'id': 'cpu-provider_azure-region_south_africa', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'ZA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0022999, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southafricanorth', 'dc_cq_id': 'south_africa_north', 'data center name': 'South Africa North', 'geo': {'geographyGroup': 'Africa', 'latitude': '-25.731340', 'longitude': '28.218370', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southafricawest', 'name': 'southafricawest', 'subscriptionId': None}], 'physicalLocation': 'Johannesburg', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0022999, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_africa_north', 'uuid': 'c2c521d5-5612-41ec-81f6-cc2cbfdc2840', 'id': 'cpu-provider_azure-region_south_africa_north', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'ZA-HDL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0022999, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southafricawest', 'dc_cq_id': 'south_africa_west', 'data center name': 'South Africa West', 'geo': {'geographyGroup': 'Africa', 'latitude': '-34.075691', 'longitude': '18.843266', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southafricanorth', 'name': 'southafricanorth', 'subscriptionId': None}], 'physicalLocation': 'Cape Town', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0022999, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_africa_west', 'uuid': '9c822176-e7a6-4884-9ed4-19b1d01b405e', 'id': 'cpu-provider_azure-region_south_africa_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'ZA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0022999, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southcentralus', 'dc_cq_id': 'south_central_us', 'data center name': 'South Central US', 'geo': {'geographyGroup': 'US', 'latitude': '29.4167', 'longitude': '-98.5', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/northcentralus', 'name': 'northcentralus', 'subscriptionId': None}], 'physicalLocation': 'Texas', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0009531, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_central_us', 'uuid': '8f72a475-f8d6-4b30-abf7-c2aae80f5639', 'id': 'cpu-provider_azure-region_south_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-TX', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0009531, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southindia', 'dc_cq_id': 'south_india', 'data center name': 'South India', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '12.9822', 'longitude': '80.1636', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/centralindia', 'name': 'centralindia', 'subscriptionId': None}], 'physicalLocation': 'Chennai', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.00179611, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_india', 'uuid': '3da509d5-271e-478e-9f3c-374fefc8735f', 'id': 'cpu-provider_azure-region_south_india', 'access_type': 'public', 'source': 'CCF', 'year': '2021', 'region': 'IN-MAA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.00179611, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southeastasia', 'dc_cq_id': 'southeast_asia', 'data center name': 'Southeast Asia', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '1.283', 'longitude': '103.833', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastasia', 'name': 'eastasia', 'subscriptionId': None}], 'physicalLocation': 'Singapore', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0010419, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_southeast_asia', 'uuid': '96e33403-e672-4674-af81-5aaf63af1585', 'id': 'cpu-provider_azure-region_southeast_asia', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'SG-SIN', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0010419, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'switzerlandnorth', 'dc_cq_id': 'switzerland_north', 'data center name': 'Switzerland North', 'geo': {'geographyGroup': 'Europe', 'latitude': '47.451542', 'longitude': '8.564572', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/switzerlandwest', 'name': 'switzerlandwest', 'subscriptionId': None}], 'physicalLocation': 'Zurich', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.45e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_switzerland_north', 'uuid': 'e0e4edad-b2d0-409e-a4e6-f2a187087a5c', 'id': 'cpu-provider_azure-region_switzerland_north', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CH-ZRH', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.45e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'switzerlandwest', 'dc_cq_id': 'switzerland_west', 'data center name': 'Switzerland West', 'geo': {'geographyGroup': 'Europe', 'latitude': '46.204391', 'longitude': '6.143158', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/switzerlandnorth', 'name': 'switzerlandnorth', 'subscriptionId': None}], 'physicalLocation': 'Geneva', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.45e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_switzerland_west', 'uuid': '421426be-6a4c-4d7f-a62b-8fb97e9ffd62', 'id': 'cpu-provider_azure-region_switzerland_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CH', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.45e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'uksouth', 'dc_cq_id': 'uk_south', 'data center name': 'UK South', 'geo': {'geographyGroup': 'Europe', 'latitude': '50.941', 'longitude': '-0.799', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/ukwest', 'name': 'ukwest', 'subscriptionId': None}], 'physicalLocation': 'London', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0005746, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_uk_south', 'uuid': '62089737-fb93-4cba-9d66-50277d035009', 'id': 'cpu-provider_azure-region_uk_south', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'GB-LON', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0005746, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'ukwest', 'dc_cq_id': 'uk_west', 'data center name': 'UK West', 'geo': {'geographyGroup': 'Europe', 'latitude': '53.427', 'longitude': '-3.084', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/uksouth', 'name': 'uksouth', 'subscriptionId': None}], 'physicalLocation': 'Cardiff', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0005823, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_uk_west', 'uuid': 'c0a638ec-7869-406a-b400-1673225a5479', 'id': 'cpu-provider_azure-region_uk_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'GB-CDF', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0005823, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# Failed to add data for zone: azure — unitedarabemirates. With error list index out of range
# Failed to add data for zone: azure — unitedarabemiratescentral. With error list index out of range
# Failed to add data for zone: azure — unitedarabemiratesnorth. With error list index out of range
# {'provider': 'azure', 'dc_id': 'westcentralus', 'dc_cq_id': 'west_central_us', 'data center name': 'West Central US', 'geo': {'geographyGroup': 'US', 'latitude': '40.890', 'longitude': '-110.234', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westus2', 'name': 'westus2', 'subscriptionId': None}], 'physicalLocation': 'Wyoming', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_central_us', 'uuid': '2b291f42-746a-43cc-9f50-c2ebc54d472f', 'id': 'cpu-provider_azure-region_west_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-WY', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westeurope', 'dc_cq_id': 'west_europe', 'data center name': 'West Europe', 'geo': {'geographyGroup': 'Europe', 'latitude': '52.3667', 'longitude': '4.9', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/northeurope', 'name': 'northeurope', 'subscriptionId': None}], 'physicalLocation': 'Netherlands', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008387, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_europe', 'uuid': '77fbc573-ff1c-45d9-a28a-8c6f66191310', 'id': 'cpu-provider_azure-region_west_europe', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'NL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008387, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westindia', 'dc_cq_id': 'west_india', 'data center name': 'West India', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '19.088', 'longitude': '72.868', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southindia', 'name': 'southindia', 'subscriptionId': None}], 'physicalLocation': 'Mumbai', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.00179611, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_india', 'uuid': '72a940d8-29e6-43db-b7bc-eace54f57d58', 'id': 'cpu-provider_azure-region_west_india', 'access_type': 'public', 'source': 'CCF', 'year': '2021', 'region': 'IN-BOM', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.00179611, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westus', 'dc_cq_id': 'west_us', 'data center name': 'West US', 'geo': {'geographyGroup': 'US', 'latitude': '37.783', 'longitude': '-122.417', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastus', 'name': 'eastus', 'subscriptionId': None}], 'physicalLocation': 'California', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_us', 'uuid': 'c79cc322-5702-4157-bb94-fddf429fec2d', 'id': 'cpu-provider_azure-region_west_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-CA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westus2', 'dc_cq_id': 'west_us_2', 'data center name': 'West US 2', 'geo': {'geographyGroup': 'US', 'latitude': '47.233', 'longitude': '-119.852', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westcentralus', 'name': 'westcentralus', 'subscriptionId': None}], 'physicalLocation': 'Washington', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'e4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_us_2', 'uuid': '2739d453-0832-4a7e-b6b0-df2bc20cdba3', 'id': 'cpu-provider_azure-region_west_us_2', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-WA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# ...
# {'provider': 'azure', 'dc_id': 'southcentralus', 'dc_cq_id': 'south_central_us', 'data center name': 'South Central US', 'geo': {'geographyGroup': 'US', 'latitude': '29.4167', 'longitude': '-98.5', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/northcentralus', 'name': 'northcentralus', 'subscriptionId': None}], 'physicalLocation': 'Texas', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0009531, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_central_us', 'uuid': '8f72a475-f8d6-4b30-abf7-c2aae80f5639', 'id': 'cpu-provider_azure-region_south_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-TX', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0009531, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southindia', 'dc_cq_id': 'south_india', 'data center name': 'South India', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '12.9822', 'longitude': '80.1636', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/centralindia', 'name': 'centralindia', 'subscriptionId': None}], 'physicalLocation': 'Chennai', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.00179611, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_south_india', 'uuid': '3da509d5-271e-478e-9f3c-374fefc8735f', 'id': 'cpu-provider_azure-region_south_india', 'access_type': 'public', 'source': 'CCF', 'year': '2021', 'region': 'IN-MAA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.00179611, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'southeastasia', 'dc_cq_id': 'southeast_asia', 'data center name': 'Southeast Asia', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '1.283', 'longitude': '103.833', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastasia', 'name': 'eastasia', 'subscriptionId': None}], 'physicalLocation': 'Singapore', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0010419, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_southeast_asia', 'uuid': '96e33403-e672-4674-af81-5aaf63af1585', 'id': 'cpu-provider_azure-region_southeast_asia', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'SG-SIN', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0010419, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'switzerlandnorth', 'dc_cq_id': 'switzerland_north', 'data center name': 'Switzerland North', 'geo': {'geographyGroup': 'Europe', 'latitude': '47.451542', 'longitude': '8.564572', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/switzerlandwest', 'name': 'switzerlandwest', 'subscriptionId': None}], 'physicalLocation': 'Zurich', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.45e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_switzerland_north', 'uuid': 'e0e4edad-b2d0-409e-a4e6-f2a187087a5c', 'id': 'cpu-provider_azure-region_switzerland_north', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CH-ZRH', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.45e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'switzerlandwest', 'dc_cq_id': 'switzerland_west', 'data center name': 'Switzerland West', 'geo': {'geographyGroup': 'Europe', 'latitude': '46.204391', 'longitude': '6.143158', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/switzerlandnorth', 'name': 'switzerlandnorth', 'subscriptionId': None}], 'physicalLocation': 'Geneva', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 1.45e-05, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_switzerland_west', 'uuid': '421426be-6a4c-4d7f-a62b-8fb97e9ffd62', 'id': 'cpu-provider_azure-region_switzerland_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'CH', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 1.45e-05, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'uksouth', 'dc_cq_id': 'uk_south', 'data center name': 'UK South', 'geo': {'geographyGroup': 'Europe', 'latitude': '50.941', 'longitude': '-0.799', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/ukwest', 'name': 'ukwest', 'subscriptionId': None}], 'physicalLocation': 'London', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0005746, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_uk_south', 'uuid': '62089737-fb93-4cba-9d66-50277d035009', 'id': 'cpu-provider_azure-region_uk_south', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'GB-LON', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0005746, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'ukwest', 'dc_cq_id': 'uk_west', 'data center name': 'UK West', 'geo': {'geographyGroup': 'Europe', 'latitude': '53.427', 'longitude': '-3.084', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/uksouth', 'name': 'uksouth', 'subscriptionId': None}], 'physicalLocation': 'Cardiff', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0005823, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_uk_west', 'uuid': 'c0a638ec-7869-406a-b400-1673225a5479', 'id': 'cpu-provider_azure-region_uk_west', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'GB-CDF', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0005823, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# Failed to add data for zone: azure — unitedarabemirates. With error list index out of range
# Failed to add data for zone: azure — unitedarabemiratescentral. With error list index out of range
# Failed to add data for zone: azure — unitedarabemiratesnorth. With error list index out of range
# {'provider': 'azure', 'dc_id': 'westcentralus', 'dc_cq_id': 'west_central_us', 'data center name': 'West Central US', 'geo': {'geographyGroup': 'US', 'latitude': '40.890', 'longitude': '-110.234', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westus2', 'name': 'westus2', 'subscriptionId': None}], 'physicalLocation': 'Wyoming', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_central_us', 'uuid': '2b291f42-746a-43cc-9f50-c2ebc54d472f', 'id': 'cpu-provider_azure-region_west_central_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-WY', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westeurope', 'dc_cq_id': 'west_europe', 'data center name': 'West Europe', 'geo': {'geographyGroup': 'Europe', 'latitude': '52.3667', 'longitude': '4.9', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/northeurope', 'name': 'northeurope', 'subscriptionId': None}], 'physicalLocation': 'Netherlands', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008387, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_europe', 'uuid': '77fbc573-ff1c-45d9-a28a-8c6f66191310', 'id': 'cpu-provider_azure-region_west_europe', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'NL', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008387, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westindia', 'dc_cq_id': 'west_india', 'data center name': 'West India', 'geo': {'geographyGroup': 'Asia Pacific', 'latitude': '19.088', 'longitude': '72.868', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/southindia', 'name': 'southindia', 'subscriptionId': None}], 'physicalLocation': 'Mumbai', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.00179611, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_india', 'uuid': '72a940d8-29e6-43db-b7bc-eace54f57d58', 'id': 'cpu-provider_azure-region_west_india', 'access_type': 'public', 'source': 'CCF', 'year': '2021', 'region': 'IN-BOM', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.00179611, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westus', 'dc_cq_id': 'west_us', 'data center name': 'West US', 'geo': {'geographyGroup': 'US', 'latitude': '37.783', 'longitude': '-122.417', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastus', 'name': 'eastus', 'subscriptionId': None}], 'physicalLocation': 'California', 'regionCategory': 'Other', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_us', 'uuid': 'c79cc322-5702-4157-bb94-fddf429fec2d', 'id': 'cpu-provider_azure-region_west_us', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-CA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westus2', 'dc_cq_id': 'west_us_2', 'data center name': 'West US 2', 'geo': {'geographyGroup': 'US', 'latitude': '47.233', 'longitude': '-119.852', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/westcentralus', 'name': 'westcentralus', 'subscriptionId': None}], 'physicalLocation': 'Washington', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_us_2', 'uuid': '2739d453-0832-4a7e-b6b0-df2bc20cdba3', 'id': 'cpu-provider_azure-region_west_us_2', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-WA', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}
# {'provider': 'azure', 'dc_id': 'westus3', 'dc_cq_id': 'west_us_3', 'data center name': 'West US 3', 'geo': {'geographyGroup': 'US', 'latitude': '33.448376', 'longitude': '-112.074036', 'pairedRegion': [{'id': '/subscriptions/1e663d00-d459-4c1d-88ba-7877566362e6/locations/eastus', 'name': 'eastus', 'subscriptionId': None}], 'physicalLocation': 'Phoenix', 'regionCategory': 'Recommended', 'regionType': 'Physical'}, 'activity_type': 'cpu', 'activity_sub_type': 'nc64as_t4_v3', 'activity_sub_type_properties': {'num_cpus': 4}, 'duration_int': 1, 'duration_type': 'hour', 'emission_details': {'co2e': 0.0008227, 'co2e_unit': 'kg', 'co2e_calculation_method': 'ar4', 'co2e_calculation_origin': 'source', 'emission_factor': {'activity_id': 'cpu-provider_azure-region_west_us_3', 'uuid': '90dd5214-3894-4c55-b153-05dedbdd7134', 'id': 'cpu-provider_azure-region_west_us_3', 'access_type': 'public', 'source': 'CCF', 'year': '2022', 'region': 'US-AZ', 'category': 'Cloud Computing - CPU', 'lca_activity': 'use_phase', 'data_quality_flags': ['notable_methodological_variance']}, 'constituent_gases': {'co2e_total': 0.0008227, 'co2e_other': None, 'co2': None, 'ch4': None, 'n2o': None}}}

# %%
with open("instance_data.json", "w") as f:
    f.write(json.dumps(instance_data, indent=4))

# %%
df = pd.read_json("instance_data.json")
df["lat"] = df["geo"].apply(lambda x: x["latitude"])
df["lon"] = df["geo"].apply(lambda x: x["longitude"])
df['co2e'] = df["emission_details"].apply(lambda x: x["co2e"])

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scattergeo(
        lon = df['lon'],
        lat = df['lat'],
        text = df['dc_cq_id'] + " — " + df['co2e'].astype('str'),
        mode = 'markers',
        marker = dict(
                color = df['co2e'],
                colorscale = "RdYlGn_r",
                size = 10,
                colorbar = dict(
                titleside = "right",
                outlinecolor = "rgba(68, 68, 68, 0)",
                ticks = "outside",
                showticksuffix = "last",
                dtick = 0.1
                        )
        )
        
        ))

fig.update_layout(
        title = 'CO2e per hour',
        width=1000,
        height=500,
        geo = dict(
                scope = 'world',
                showland = True,
                landcolor = "rgb(212, 212, 212)",
                subunitcolor = "rgb(255, 255, 255)",
                countrycolor = "rgb(255, 255, 255)",
                showlakes = True,
                lakecolor = "rgb(255, 255, 255)",
                showsubunits = True,
                showcountries = True,
                resolution = 50,
                projection = dict(
                        type = 'mercator',
                        rotation_lon = -100
        )
    ),
    )
fig.show()

# %%
import plotly.express as px
fig = px.scatter_geo(df, 
                lat="lat",
                lon="lon",
                color="co2e",
                hover_name="dc_cq_id", 
                size=[0.8]*len(df),
                projection="natural earth",
                color_continuous_scale = "RdYlGn_r",
                )
fig.show()
